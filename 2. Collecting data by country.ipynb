# %%
import pandas as pd

# %%
df = pd.read_excel('Data_total.xlsx')

# %%
df
# Out:
#                                        Series Name        Series Code  \
# 1057   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1060   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1061   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1064   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1065   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1068   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1069   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1071   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1072   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1074   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1075   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1085   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1092   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1102   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1108   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1120   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1124   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1125   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1134   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1139   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1146   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1157   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1158   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1161   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1174   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1179   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1180   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1181   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1194   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1204   Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# ...                                            ...                ...
# 25627                             Trade (% of GDP)     NE.TRD.GNFS.ZS
# 25637                             Trade (% of GDP)     NE.TRD.GNFS.ZS
# 25644                             Trade (% of GDP)     NE.TRD.GNFS.ZS
# 25654                             Trade (% of GDP)     NE.TRD.GNFS.ZS
# 25660                             Trade (% of GDP)     NE.TRD.GNFS.ZS
# 25672                             Trade (% of GDP)     NE.TRD.GNFS.ZS
# 25676                             Trade (% of GDP)     NE.TRD.GNFS.ZS
# 25677                             Trade (% of GDP)     NE.TRD.GNFS.ZS
# 25686                             Trade (% of GDP)     NE.TRD.GNFS.ZS
# 25691                             Trade (% of GDP)     NE.TRD.GNFS.ZS
# 25698                             Trade (% of GDP)     NE.TRD.GNFS.ZS
# 25709                             Trade (% of GDP)     NE.TRD.GNFS.ZS
# 25710                             Trade (% of GDP)     NE.TRD.GNFS.ZS
# 25713                             Trade (% of GDP)     NE.TRD.GNFS.ZS
# 25726                             Trade (% of GDP)     NE.TRD.GNFS.ZS
# 25731                             Trade (% of GDP)     NE.TRD.GNFS.ZS
# 25732                             Trade (% of GDP)     NE.TRD.GNFS.ZS
# 25733                             Trade (% of GDP)     NE.TRD.GNFS.ZS
# 25746                             Trade (% of GDP)     NE.TRD.GNFS.ZS
# 25756                             Trade (% of GDP)     NE.TRD.GNFS.ZS
# 25762                             Trade (% of GDP)     NE.TRD.GNFS.ZS
# 25771                             Trade (% of GDP)     NE.TRD.GNFS.ZS
# 25772                             Trade (% of GDP)     NE.TRD.GNFS.ZS
# 25775                             Trade (% of GDP)     NE.TRD.GNFS.ZS
# 25786                             Trade (% of GDP)     NE.TRD.GNFS.ZS
# 25787                             Trade (% of GDP)     NE.TRD.GNFS.ZS
# 25799                             Trade (% of GDP)     NE.TRD.GNFS.ZS
# 25813                             Trade (% of GDP)     NE.TRD.GNFS.ZS
# 25832                             Trade (% of GDP)     NE.TRD.GNFS.ZS
# 25836                             Trade (% of GDP)     NE.TRD.GNFS.ZS
#
#              Country Name Country Code      1960       1961       1962  \
# 1057            Australia          AUS       NaN        NaN        NaN
# 1060               France          FRA       NaN        NaN        NaN
# 1061              Germany          DEU       NaN        NaN        NaN
# 1064                Italy          ITA       NaN        NaN        NaN
# 1065                Japan          JPN       NaN        NaN        NaN
# 1068          Netherlands          NLD       NaN        NaN        NaN
# 1069   Russian Federation          RUS       NaN        NaN        NaN
# 1071                Spain          ESP       NaN        NaN        NaN
# 1072          Switzerland          CHE       NaN        NaN        NaN
# 1074       United Kingdom          GBR       NaN        NaN        NaN
# 1075        United States          USA       NaN        NaN        NaN
# 1085              Austria          AUT       NaN        NaN        NaN
# 1092              Belgium          BEL       NaN        NaN        NaN
# 1102             Bulgaria          BGR       NaN        NaN        NaN
# 1108               Canada          CAN       NaN        NaN        NaN
# 1120              Croatia          HRV       NaN        NaN        NaN
# 1124       Czech Republic          CZE       NaN        NaN        NaN
# 1125              Denmark          DNK       NaN        NaN        NaN
# 1134              Estonia          EST       NaN        NaN        NaN
# 1139              Finland          FIN       NaN        NaN        NaN
# 1146               Greece          GRC       NaN        NaN        NaN
# 1157              Hungary          HUN       NaN        NaN        NaN
# 1158              Iceland          ISL       NaN        NaN        NaN
# 1161              Ireland          IRL       NaN        NaN        NaN
# 1174               Latvia          LVA       NaN        NaN        NaN
# 1179        Liechtenstein          LIE       NaN        NaN        NaN
# 1180            Lithuania          LTU       NaN        NaN        NaN
# 1181           Luxembourg          LUX       NaN        NaN        NaN
# 1194               Monaco          MCO       NaN        NaN        NaN
# 1204          New Zealand          NZL       NaN        NaN        NaN
# ...                   ...          ...       ...        ...        ...
# 25627       United States          USA       NaN        NaN        NaN
# 25637             Austria          AUT       NaN        NaN        NaN
# 25644             Belgium          BEL       NaN        NaN        NaN
# 25654            Bulgaria          BGR       NaN        NaN        NaN
# 25660              Canada          CAN       NaN  35.900781  35.602785
# 25672             Croatia          HRV       NaN        NaN        NaN
# 25676      Czech Republic          CZE       NaN        NaN        NaN
# 25677             Denmark          DNK       NaN        NaN        NaN
# 25686             Estonia          EST       NaN        NaN        NaN
# 25691             Finland          FIN       NaN        NaN        NaN
# 25698              Greece          GRC  24.47376  23.604745  23.108516
# 25709             Hungary          HUN       NaN        NaN        NaN
# 25710             Iceland          ISL       NaN        NaN        NaN
# 25713             Ireland          IRL       NaN        NaN        NaN
# 25726              Latvia          LVA       NaN        NaN        NaN
# 25731       Liechtenstein          LIE       NaN        NaN        NaN
# 25732           Lithuania          LTU       NaN        NaN        NaN
# 25733          Luxembourg          LUX       NaN        NaN        NaN
# 25746              Monaco          MCO       NaN        NaN        NaN
# 25756         New Zealand          NZL       NaN        NaN        NaN
# 25762              Norway          NOR       NaN        NaN        NaN
# 25771              Poland          POL       NaN        NaN        NaN
# 25772            Portugal          PRT       NaN        NaN        NaN
# 25775             Romania          ROU       NaN        NaN        NaN
# 25786     Slovak Republic          SVK       NaN        NaN        NaN
# 25787            Slovenia          SVN       NaN        NaN        NaN
# 25799              Sweden          SWE  42.49063  40.282429  39.608477
# 25813             Ukraine          UKR       NaN        NaN        NaN
# 25832           Euro area          EMU       NaN        NaN        NaN
# 25836      European Union          EUU       NaN        NaN        NaN
#
#             1963       1964       1965  ...         2010        2011  \
# 1057         NaN        NaN        NaN  ...          NaN         NaN
# 1060         NaN        NaN        NaN  ...          NaN         NaN
# 1061         NaN        NaN        NaN  ...          NaN         NaN
# 1064         NaN        NaN        NaN  ...          NaN         NaN
# 1065         NaN        NaN        NaN  ...          NaN         NaN
# 1068         NaN        NaN        NaN  ...          NaN         NaN
# 1069         NaN        NaN        NaN  ...          NaN         NaN
# 1071         NaN        NaN        NaN  ...          NaN         NaN
# 1072         NaN        NaN        NaN  ...          NaN         NaN
# 1074         NaN        NaN        NaN  ...          NaN         NaN
# 1075         NaN        NaN        NaN  ...          NaN         NaN
# 1085         NaN        NaN        NaN  ...          NaN         NaN
# 1092         NaN        NaN        NaN  ...          NaN         NaN
# 1102         NaN        NaN        NaN  ...          NaN         NaN
# 1108         NaN        NaN        NaN  ...          NaN         NaN
# 1120         NaN        NaN        NaN  ...          NaN         NaN
# 1124         NaN        NaN        NaN  ...          NaN         NaN
# 1125         NaN        NaN        NaN  ...          NaN         NaN
# 1134         NaN        NaN        NaN  ...          NaN         NaN
# 1139         NaN        NaN        NaN  ...          NaN         NaN
# 1146         NaN        NaN        NaN  ...          NaN         NaN
# 1157         NaN        NaN        NaN  ...          NaN         NaN
# 1158         NaN        NaN        NaN  ...          NaN         NaN
# 1161         NaN        NaN        NaN  ...          NaN         NaN
# 1174         NaN        NaN        NaN  ...          NaN         NaN
# 1179         NaN        NaN        NaN  ...          NaN         NaN
# 1180         NaN        NaN        NaN  ...          NaN         NaN
# 1181         NaN        NaN        NaN  ...          NaN         NaN
# 1194         NaN        NaN        NaN  ...          NaN         NaN
# 1204         NaN        NaN        NaN  ...          NaN         NaN
# ...          ...        ...        ...  ...          ...         ...
# 25627        NaN        NaN        NaN  ...    28.057952   30.789294
# 25637        NaN        NaN        NaN  ...    99.019796  105.102789
# 25644        NaN        NaN        NaN  ...   149.997673  161.493724
# 1139          NaN   NaN
# 1146          NaN   NaN
# 1157          NaN   NaN
# 1158          NaN   NaN
# 1161          NaN   NaN
# 1174          NaN   NaN
# 1179          NaN   NaN
# 1180          NaN   NaN
# 1181          NaN   NaN
# 1194          NaN   NaN
# 1204          NaN   NaN
# ...           ...   ...
# 25627   27.543903   NaN
# 25637  107.790262   NaN
# 25644  165.314652   NaN
# 25654  131.250967   NaN
# 25660   66.223971   NaN
# 25672  101.878193   NaN
# 25676  150.389135   NaN
# 25677  105.236145   NaN
# 25686  145.000502   NaN
# 25691   77.854410   NaN
# 25698   72.519700   NaN
# 25709  165.503989   NaN
# 25710   91.349444   NaN
# 25713  211.511074   NaN
# 25726  122.793208   NaN
# 25731         NaN   NaN
# 25732  149.299813   NaN
# 25733  387.103340   NaN
# 25746         NaN   NaN
# 25756   56.399746   NaN
# 25762   71.074186   NaN
# 25771  107.744362   NaN
# 25772   86.956757   NaN
# 25775   86.494919   NaN
# 25786  190.155092   NaN
# 25787  162.476886   NaN
# 25799   89.074706   NaN
# 25813   99.018660   NaN
# 25832   88.055029   NaN
# 25836   86.627659   NaN
#
# [1160 rows x 64 columns]

# %%
series = sorted(list(set(df['Series Name'])))

# %%
series
# Out:
# ['Agricultural methane emissions (% of total)',
#  'Agricultural nitrous oxide emissions (% of total)',
#  'Air transport, freight (million ton-km)',
#  'Air transport, passengers carried',
#  'Air transport, registered carrier departures worldwide',
#  'Alternative and nuclear energy (% of total energy use)',
#  'CO2 emissions (metric tons per capita)',
#  'CO2 emissions from electricity and heat production, total (% of total fuel combustion)',
#  'CO2 emissions from gaseous fuel consumption (% of total)',
#  'CO2 emissions from liquid fuel consumption (% of total)',
#  'CO2 emissions from manufacturing industries and construction (% of total fuel combustion)',
#  'CO2 emissions from other sectors, excluding residential buildings and commercial and public services (% of total fuel combustion)',
#  'CO2 emissions from residential buildings and commercial and public services (% of total fuel combustion)',
#  'CO2 emissions from solid fuel consumption (% of total)',
#  'CO2 emissions from transport (% of total fuel combustion)',
#  'CO2 intensity (kg per kg of oil equivalent energy use)',
#  'Cereal yield (kg per hectare)',
#  'Electric power consumption (kWh per capita)',
#  'Electricity production from hydroelectric sources (% of total)',
#  'Electricity production from nuclear sources (% of total)',
#  'Electricity production from oil, gas and coal sources (% of total)',
#  'Electricity production from renewable sources, excluding hydroelectric (% of total)',
#  'Energy related methane emissions (% of total)',
#  'Energy use (kg of oil equivalent per capita)',
#  'Forest area (% of land area)',
#  'GDP per capita growth (annual %)',
#  'Land under cereal production (hectares)',
#  'Population growth (annual %)',
#  'Trade (% of GDP)']

# %%
df.head()
# Out:
#                                       Series Name        Series Code  \
# 1057  Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1060  Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1061  Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1064  Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
# 1065  Agricultural methane emissions (% of total)  EN.ATM.METH.AG.ZS
#
#      Country Name Country Code  1960  1961  1962  1963  1964  1965  ...   \
# 1057    Australia          AUS   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1060       France          FRA   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1061      Germany          DEU   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1064        Italy          ITA   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 1065        Japan          JPN   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#       2010  2011  2012  2013  2014  2015  2016  2017  2018  2019
# 1057   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1060   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1061   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1064   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
# 1065   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 64 columns]

# %%
countries = set(df['Country Name'])

# %%
with pd.ExcelWriter('Data_by_country.xlsx') as writer:  
    for item in countries:
        df[df['Country Name'] == item].to_excel(writer, sheet_name='{}'.format(item))
